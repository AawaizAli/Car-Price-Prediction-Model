# %%
import pandas as pd

# %%
df = pd.read_csv('usedready.csv')

# %%
df
# Out:
#                                      Name           Price  Body Type  \
# 0    Honda City 1.3 i-VTEC Prosmatec 2016  PKR 34.25 lacs      Sedan
# 1   Honda Civic VTi Oriel 1.8 i-VTEC 2014     PKR 38 lacs      Sedan
# 2                      Toyota Aqua S 2014  PKR 35.25 lacs  Hatchback
# 3                       Suzuki Bolan 2007    PKR 6.3 lacs        NaN
# 4        Toyota Corolla GLi 1.3 VVTi 2012   PKR 26.5 lacs      Sedan
# ..                                    ...             ...        ...
# 58                KIA Picanto 1.0 AT 2020   PKR 28.5 lacs  Hatchback
# 59  Honda Civic Oriel 1.8 i-VTEC CVT 2020  Call for price      Sedan
# 60          Toyota Fortuner 2.7 VVTi 2013     PKR 72 lacs        SUV
# 61                      MG HS Trophy 2022  Call for price  Crossover
# 62       Toyota Fortuner 2.8 Sigma 4 2021  Call for price        SUV
#
#    Displacement Transmission  Seating Capacity    Odometer
# 0       1300 cc    Automatic               NaN   89,000 km
# ...

# %%
data = df

# %%
data
# Out:
#                                      Name           Price  Body Type  \
# 0    Honda City 1.3 i-VTEC Prosmatec 2016  PKR 34.25 lacs      Sedan
# 1   Honda Civic VTi Oriel 1.8 i-VTEC 2014     PKR 38 lacs      Sedan
# 2                      Toyota Aqua S 2014  PKR 35.25 lacs  Hatchback
# 3                       Suzuki Bolan 2007    PKR 6.3 lacs        NaN
# 4        Toyota Corolla GLi 1.3 VVTi 2012   PKR 26.5 lacs      Sedan
# ..                                    ...             ...        ...
# 58                KIA Picanto 1.0 AT 2020   PKR 28.5 lacs  Hatchback
# 59  Honda Civic Oriel 1.8 i-VTEC CVT 2020  Call for price      Sedan
# 60          Toyota Fortuner 2.7 VVTi 2013     PKR 72 lacs        SUV
# 61                      MG HS Trophy 2022  Call for price  Crossover
# 62       Toyota Fortuner 2.8 Sigma 4 2021  Call for price        SUV
#
#    Displacement Transmission  Seating Capacity    Odometer
# 0       1300 cc    Automatic               NaN   89,000 km
# ...

# %%
# Remove the 'PKR' and 'lacs' from the Price column and handle rows with 'Call for price'
data['Price'] = data['Price'].str.replace('PKR ', '').str.replace(' lacs', '')
data = data[data['Price'] != 'Call for price']

# Convert cleaned price data to float, assuming 'lacs' means 'hundred thousands'
data['Price'] = data['Price'].astype(float) * 100000

# Show the cleaned data
cleaned_data_preview = data.head()
cleaned_data_preview
# Out:
# /var/folders/qq/825c9lpx42x0rhxk9smb4c8h0000gq/T/ipykernel_15394/2552331315.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Price'] = data['Price'].astype(float) * 100000
#                                     Name      Price  Body Type Displacement  \
# 0   Honda City 1.3 i-VTEC Prosmatec 2016  3425000.0      Sedan      1300 cc
# 1  Honda Civic VTi Oriel 1.8 i-VTEC 2014  3800000.0      Sedan      1800 cc
# 2                     Toyota Aqua S 2014  3525000.0  Hatchback      1500 cc
# 3                      Suzuki Bolan 2007   630000.0        NaN       800 cc
# 4       Toyota Corolla GLi 1.3 VVTi 2012  2650000.0      Sedan      1300 cc
#
#   Transmission  Seating Capacity    Odometer
# ...

# %%
# Remove 'cc' from the Displacement column and convert to integer type
data['Displacement'] = data['Displacement'].str.replace(' cc', '').astype(float)

# Show the cleaned data
cleaned_displacement_data_preview = data.head()
cleaned_displacement_data_preview
# Out:
# /var/folders/qq/825c9lpx42x0rhxk9smb4c8h0000gq/T/ipykernel_15394/2369430077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Displacement'] = data['Displacement'].str.replace(' cc', '').astype(float)
#                                     Name      Price  Body Type  Displacement  \
# 0   Honda City 1.3 i-VTEC Prosmatec 2016  3425000.0      Sedan        1300.0
# 1  Honda Civic VTi Oriel 1.8 i-VTEC 2014  3800000.0      Sedan        1800.0
# 2                     Toyota Aqua S 2014  3525000.0  Hatchback        1500.0
# 3                      Suzuki Bolan 2007   630000.0        NaN         800.0
# 4       Toyota Corolla GLi 1.3 VVTi 2012  2650000.0      Sedan        1300.0
#
#   Transmission  Seating Capacity    Odometer
# ...

# %%
# Remove 'km' from the Odometer column and convert to integer type
data['Odometer'] = data['Odometer'].str.replace(' km', '').str.replace(',', '').astype(int)

# Show the cleaned data
cleaned_odometer_data_preview = data.head()
cleaned_odometer_data_preview
# Out:
# /var/folders/qq/825c9lpx42x0rhxk9smb4c8h0000gq/T/ipykernel_15394/2766230448.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Odometer'] = data['Odometer'].str.replace(' km', '').str.replace(',', '').astype(int)
#                                     Name      Price  Body Type  Displacement  \
# 0   Honda City 1.3 i-VTEC Prosmatec 2016  3425000.0      Sedan        1300.0
# 1  Honda Civic VTi Oriel 1.8 i-VTEC 2014  3800000.0      Sedan        1800.0
# 2                     Toyota Aqua S 2014  3525000.0  Hatchback        1500.0
# 3                      Suzuki Bolan 2007   630000.0        NaN         800.0
# 4       Toyota Corolla GLi 1.3 VVTi 2012  2650000.0      Sedan        1300.0
#
#   Transmission  Seating Capacity  Odometer
# ...

# %%
# Replace NaN values in the 'Transmission' column with 'Manual'
data['Transmission'] = data['Transmission'].fillna('Manual')

# Show the updated data
updated_transmission_data_preview = data.head()
# Out:
# /var/folders/qq/825c9lpx42x0rhxk9smb4c8h0000gq/T/ipykernel_15394/2230994246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Transmission'] = data['Transmission'].fillna('Manual')
#                                     Name      Price  Body Type  Displacement  \
# 0   Honda City 1.3 i-VTEC Prosmatec 2016  3425000.0      Sedan        1300.0
# 1  Honda Civic VTi Oriel 1.8 i-VTEC 2014  3800000.0      Sedan        1800.0
# 2                     Toyota Aqua S 2014  3525000.0  Hatchback        1500.0
# 3                      Suzuki Bolan 2007   630000.0        NaN         800.0
# 4       Toyota Corolla GLi 1.3 VVTi 2012  2650000.0      Sedan        1300.0
#
#   Transmission  Seating Capacity  Odometer
# ...
